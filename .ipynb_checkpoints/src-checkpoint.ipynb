# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Using cached google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2
# WARNING: You are using pip version 20.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\users\legion\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np
from google_play_scraper import Sort, reviews
from pathlib import Path

# %%
def makeCsv(fileName):
    filepath = Path(f'dataset/{fileName}')  
    filepath.parent.mkdir(parents=True, exist_ok=True)  
    df.to_csv(filepath)

# %%
result, continuation_token = reviews(
    'id.go.kemensos.pelaporan',
    lang='id', 
    country='id', 
    sort=Sort.MOST_RELEVANT, 
    count=2000, 
    filter_score_with=None
)
df = pd.DataFrame(np.array(result),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))

# %%
df
# Out:
#                                   reviewId         userName  \
# 0     39462333-f159-4bc7-a667-0816f8295cd5    Nimas Indrati
# 1     3d31a173-ffe8-49be-802a-8106565071d9    Yogi Setiawan
# 2     feec1048-4bd1-4f3c-9130-6d134e9673ef   Rendi Sianturi
# 3     0f58e0a6-ed24-4dd6-b214-08a2d00e737e    Oon Brevianto
# 4     eba7fede-8a75-4d13-9326-cfbbb39c0838  Mulyono Gunawan
# ...                                    ...              ...
# 1995  8bc398dc-b25f-48c2-8a5f-0f9b852d2dc7       Hiberrr Tv
# 1996  07c2cf2d-09dd-4e8c-8cd7-1200e4886179    Bagus Sassuke
# 1997  29d1ed8c-c2f8-4a22-a0f4-86623ad6287b    Agus Salym ST
# 1998  f4bba4ab-f595-492e-a512-92515d60f2ee   Cahyo Railfans
# 1999  c060ac49-81fb-44bb-ba07-d162af01ede6       riky ahmad
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/AD5-W...
# 1     https://play-lh.googleusercontent.com/a/AEdFTp...
# 2     https://play-lh.googleusercontent.com/a-/AD5-W...
# 3     https://play-lh.googleusercontent.com/a-/AD5-W...
# 4     https://play-lh.googleusercontent.com/a/AEdFTp...
# ...                                                 ...
# 1995  https://play-lh.googleusercontent.com/a-/AD5-W...
# 1996  https://play-lh.googleusercontent.com/a-/AD5-W...
# 1997  https://play-lh.googleusercontent.com/a-/AD5-W...
# 1998  https://play-lh.googleusercontent.com/a-/AD5-W...
# 1999  https://play-lh.googleusercontent.com/a-/AD5-W...
#
#                                                 content  score  thumbsUpCount  \
# 0     Tidak pernah sempurna. Dulu sulit login, pas b...      1             10
# 1     Eror terus ketika pengajuan usulan, sinyal sta...      1            229
# 2     Buruk banget aplikasi ini, emangnya tidak ada ...      1             50
# 3     Sudah Updated versi Terakhir tapi Tetap Tidak ...      1            962
# 4     Tidak bisa login, padahal email dan password s...      1            406
# ...                                                 ...    ...            ...
# 1995  Mohon maaf ini niat membantu kami rakyat kecil...      1              0
# 1996  Error JSON parse terus pas buat akun baru ,tol...      5              0
# 1997                        Login slalu gagal dan error      1              0
# 1998  Aplikasi apaan ini tiap mau ngisi propinsi mes...      1              0
# 1999  Apakah pak mentri sosial juga pengguna aplikas...      1              0
#
#      reviewCreatedVersion                  at replyContent repliedAt
# 0                   1.0.7 2022-12-13 14:35:26         None      None
# 1                   1.0.7 2022-12-01 09:40:50         None      None
# 2                   1.0.7 2022-12-08 17:32:58         None      None
# 3                   1.0.7 2022-10-06 13:49:22         None      None
# 4                   1.0.7 2022-10-24 03:06:48         None      None
# ...                   ...                 ...          ...       ...
# 1995                1.0.7 2022-10-08 05:40:49         None      None
# 1996                1.0.7 2022-10-10 21:42:32         None      None
# 1997                1.0.7 2022-10-14 18:32:05         None      None
# 1998                1.0.7 2022-10-13 11:04:26         None      None
# 1999                1.0.7 2022-10-07 14:06:11         None      None
#
# [2000 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt'],
#       dtype='object')

# %%
makeCsv('data-of-kemensospelaporan-2000-responses-id.csv')
